# %%
import pandas as pd
df = pd.read_excel('score.xlsx',index_col='지원번호')

# %% [markdown]
# 데이터 수정

# %%
# replace : 데이터값을 변경, inplace=True 지정
# 해당되는 값을 다른 값으로 변경
df['학교'].replace({'구로고':'가산고'},inplace=True)
df['학교'].replace({'구로고':'가산고','디지털고':'단지고'})

# 특정컬럼 값 변경 
# 컬럼 = 변경값을 입력
df['SW특기'] = df['SW특기'].str.lower() # 소문자
df['SW특기'].str.upper()   # 대문자
df['SW특기'].str.capitalize() # 첫글자대문자
df['키'] = 200

# 컬럼명 = 문자+문자
df['학교'] = df['학교']+'등학교'


# 특정셀 값 변경
df.loc['1번','국어'] = 100
df.loc['2번',['국어','영어']] = 10
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_13408\640799215.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['학교'].replace({'구로고':'가산고'},inplace=True)

# %% [markdown]
# 데이터 추가
# * 컬럼 추가 : df[컬럼명]
# * row 추가 : df.loc[index명]

# %%
## 데이터 추가
## 컬럼에 없는 컬럼 이름을 입력하면 컬럼이 추가 됨.
df['합계'] = 0
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']
df['평균'] = df['합계']/5

# %% [markdown]
# 조건식을 사용해서 값변경

# %%
# 결과컬럼 추가
df['결과'] = 'Fail'

# 결과컬럼에 -> 조건식을 사용해서 값을 변경
filt = df['합계']>=400
df.loc[filt,'결과'] = 'Pass'

## 국어점수가 90점이상이면 df['합산']+100
filt = df['국어']>=90
df.loc[filt,'합산'] = df.loc[filt,'합산']+100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '합산'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 10
#       8 ## 국어점수가 90점이상이면 df['합산']+100
#       9 filt = df['국어']>=90
# ---> 10 df.loc[filt,'합산'] = df.loc[filt,'합산']+100
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1065, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1061 for i, key in enumerate(tup):
#    1062     if is_label_like(key):
#    1063         # We don't need to check for tuples here because those are
#    1064         #  caught by the _is_nested_tuple_indexer check above.
# -> 1065         section = self._getitem_axis(key, axis=i)
#    1067         # We should never have a scalar section here, because
#    1068         #  _getitem_lowerdim is only called after a check for
#    1069         #  is_scalar_access, which that would be.
#    1070         if section.ndim == self.ndim:
#    1071             # we're in the middle of slicing through a MultiIndex
#    1072             # revise the key wrt to `section` by inserting an _NS
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4287, in NDFrame.xs(self, key, axis, level, drop_level)
#    4285 if axis == 1:
#    4286     if drop_level:
# -> 4287         return self[key]
#    4288     index = self.columns
#    4289 else:
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '합산'

# %% [markdown]
# 데이터 삭제
# - columns
# - index

# %% [markdown]
# drop - columns

# %%
# 데이터 삭제 - drop : columns, 적용 : inplace = True
df.drop(columns=['합산'],inplace=True)
# 컬럼 2개 삭제
df.drop(columns=['국어','영어'])
df.drop(columns=['합계','평균','결과'])

# 전체컬럼의 슬라이싱을 가지고 특정컬럼을 삭제할수 있음.
df.columns[0]
df.columns[3:5]
df.drop(columns=df.columns[3:5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # 데이터 삭제 - drop : columns, 적용 : inplace = True
# ----> 2 df.drop(columns=['합산'],inplace=True)
#       3 # 컬럼 2개 삭제
#       4 # df.drop(columns=['국어','영어'])
#       5 # df.drop(columns=['합계','평균','결과'])
#    (...)
#       9 # df.columns[3:5]
#      10 # df.drop(columns=df.columns[3:5])
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\kosmo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['합산'] not found in axis"

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'], dtype='object', name='지원번호')

# %% [markdown]
# drop - index삭제

# %%
# drop 삭제 - index(row값 삭제) : inplace = True 반영
df.drop(index='1번')
df.head(1)
# Out:
#        이름      학교    키   국어  영어   수학  과학  사회    SW특기   합계    평균    결과
# 지원번호
# 1번    강나래  가산고등학교  200  100  85  100  95  85  python  465  93.0  Pass

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'], dtype='object', name='지원번호')

# %%
# 김이 포함되어 있는 학생을 삭제하시오.
filt = df['이름'].str.contains('김')
filt
df.drop(index=df[filt].index)

# 수학 80점 미만 삭제
filt = df['수학']<80
filt
# 조건식을 이용한 삭제
df.drop(index=df[filt].index)
# Out:
#        이름       학교    키   국어   영어   수학  과학  사회        SW특기   합계    평균    결과
# 지원번호
# 1번    강나래   가산고등학교  200  100   85  100  95  85      python  465  93.0  Pass
# 2번    강태원   가산고등학교  200   10   10   50  55  25        java  150  30.0  Fail
# 3번    강호림   가산고등학교  200   80   75   70  80  75  javascript  380  76.0  Fail
# 6번    박동현  디지털고등학교  200   80  100   95  85  80           c  440  88.0  Pass
# 7번    박혜정  디지털고등학교  200   55   65   45  40  35      python  240  48.0  Fail
# 8번    승근열  디지털고등학교  200  100   85   90  95  95          c#  465  93.0  Pass

# %% [markdown]
# row 추가

# %%
# row 추가 - index이름 추가해서 입력하면 가능, 입력형태 list입력하면 됨.
df.loc['9번'] = ['유승찬','디지털고등학교',184,100,100,100,100,100,'Django',100*5,100/5,'Pass']

# %%
# 9번 디지털고등학교 -> 가산고등학교, 'Django' -> 'Python'
df.loc['9번',['학교','SW특기']] = ['가산고등학교','Python']
df.loc['7번','이름'] = '김혜정'
df.tail(3)
# Out:
#        이름       학교    키   국어   영어   수학   과학   사회    SW특기   합계    평균    결과
# 지원번호
# 7번    김혜정  디지털고등학교  200   55   65   45   40   35  python  240  48.0  Fail
# 8번    승근열  디지털고등학교  200  100   85   90   95   95      c#  465  93.0  Pass
# 9번    유승찬   가산고등학교  184  100  100  100  100  100  Python  500  20.0  Pass

# %%
df
# Out:
#        이름       학교    키   국어   영어   수학   과학   사회        SW특기   합계    평균    결과
# 지원번호
# 1번    강나래   가산고등학교  200  100   85  100   95   85      python  465  93.0  Pass
# 2번    강태원   가산고등학교  200   10   10   50   55   25        java  150  30.0  Fail
# 3번    강호림   가산고등학교  200   80   75   70   80   75  javascript  380  76.0  Fail
# 4번    김수찬   가산고등학교  200   40   60   70   75   80         NaN  325  65.0  Fail
# 5번    김재욱   가산고등학교  200   15   20   10   35   10         NaN   90  18.0  Fail
# 6번    박동현  디지털고등학교  200   80  100   95   85   80           c  440  88.0  Pass
# 7번    박혜정  디지털고등학교  200   55   65   45   40   35      python  240  48.0  Fail
# 8번    승근열  디지털고등학교  200  100   85   90   95   95          c#  465  93.0  Pass
# 9번    유승찬  디지털고등학교  184  100  100  100  100  100      Django  500  20.0  Pass

# %%
df
# Out:
#        이름       학교    키   국어   영어   수학   과학   사회        SW특기   합계    평균    결과
# 지원번호
# 1번    강나래   가산고등학교  200  100   85  100   95   85      python  465  93.0  Pass
# 2번    강태원   가산고등학교  200   10   10   50   55   25        java  150  30.0  Fail
# 3번    강호림   가산고등학교  200   80   75   70   80   75  javascript  380  76.0  Fail
# 4번    김수찬   가산고등학교  200   40   60   70   75   80         NaN  325  65.0  Fail
# 5번    김재욱   가산고등학교  200   15   20   10   35   10         NaN   90  18.0  Fail
# 6번    박동현  디지털고등학교  200   80  100   95   85   80           c  440  88.0  Pass
# 7번    김혜정  디지털고등학교  200   55   65   45   40   35      python  240  48.0  Fail
# 8번    승근열  디지털고등학교  200  100   85   90   95   95          c#  465  93.0  Pass
# 9번    유승찬   가산고등학교  184  100  100  100  100  100      Python  500  20.0  Pass

# %%
# row추가
